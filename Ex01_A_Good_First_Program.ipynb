# %% [markdown]
# # Ex 01
#
# ## A Good First Program
#
# ## Printing Strings in Python

# %%
# This is a comment

# Printing my first string
print("Hello World!")
print("Hello Again")
print("I like typing this.")

# Escaping Special Charachters

# Printing a string with " 
print("This is \"fun.")

# Printing a string with single quotes
print('Yay! Printing.')
print("I'd much rather you 'not'.")
print('I "said" do not touch this.')


# More on Comments
print("\n")
"""
Rule of thumb
I like to use double quotes around strings that are used for interpolation 
or that are natural language messages, and single quotes for small symbol-like 
strings, but will break the rules if the strings contain quotes, or if I forget. 
I use triple double quotes for docstrings and raw string literals for regular 
expressions even if they aren't needed.
"""
# Out:
# Hello World!
# Hello Again
# I like typing this.
# This is "fun.
# Yay! Printing.
# I'd much rather you 'not'.
# I "said" do not touch this.
# "\nRule of thumb\nI like to use double quotes around strings that are used for interpolation \nor that are natural language messages, and single quotes for small symbol-like \nstrings, but will break the rules if the strings contain quotes, or if I forget. \nI use triple double quotes for docstrings and raw string literals for regular \nexpressions even if they aren't needed.\n"

# %% [markdown]
# # Your Turn!
#
# 1.  Make your script print another line.
# 2.  Make your script print only one of the lines.
# 3.  Put a # (octothorpe) character at the beginning of a line What did it do? Try to find out what this character does.
